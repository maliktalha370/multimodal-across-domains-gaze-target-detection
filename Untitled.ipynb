# %%
import torch
import numpy as np
a =torch.tensor([0.5469, 0.3125]).numpy()
a
# Out:
# array([0.5469, 0.3125], dtype=float32)

# %%
b = torch.tensor(torch.Size[3, 224, 224]).numpy()
b[1:]
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Input In [17], in <cell line: 1>()
# ----> 1 b = torch.tensor(torch.Size[3, 224, 224]).numpy()
#       2 b[1:]
#
# RuntimeError: Could not infer dtype of types.GenericAlias

# %%
np.multiply(a, b[1:])
# Out:
# array([122.50559425,  70.        ])

# %%
import os
import cv2
DATA_DIR = '../dataset/depth/gazefollow_extended/test2/00000000/'
for f in os.listdir(DATA_DIR):
    img = cv2.imread(os.path.join(DATA_DIR, f))
    print(img.shape)
# Out:
# (480, 640, 3)
# (427, 640, 3)
# (426, 640, 3)
# (334, 500, 3)
# (480, 640, 3)
# (427, 640, 3)
# (375, 500, 3)
# (427, 640, 3)
# (438, 500, 3)
# (333, 500, 3)
# (375, 500, 3)
# (428, 640, 3)
# (480, 640, 3)
# (427, 640, 3)
# (400, 529, 3)
# (640, 478, 3)
# (425, 640, 3)
# (425, 640, 3)
# (640, 605, 3)
# (427, 640, 3)
# (425, 640, 3)
# (427, 640, 3)
# (478, 640, 3)
# (427, 640, 3)
# (332, 500, 3)
# (464, 640, 3)
# (429, 640, 3)
# (640, 425, 3)
# (427, 640, 3)
# (427, 640, 3)
# (424, 640, 3)
# (456, 640, 3)
# (427, 640, 3)
# (346, 250, 3)
# (360, 640, 3)
# (512, 640, 3)
# (333, 500, 3)
# (300, 319, 3)
# (500, 357, 3)
# (768, 1024, 3)
# (640, 426, 3)
# (480, 640, 3)
# (417, 640, 3)
# (426, 640, 3)
# (400, 300, 3)
# (640, 539, 3)
# (333, 500, 3)
# (1066, 1600, 3)
# (346, 640, 3)
# (522, 640, 3)
# (480, 640, 3)
# (480, 640, 3)
# (511, 640, 3)
# (360, 640, 3)
# (237, 320, 3)
# (640, 423, 3)
# (328, 500, 3)
# (480, 640, 3)
# (375, 500, 3)
# (375, 500, 3)
# (426, 640, 3)
# (458, 640, 3)
# ...

# %%
cv2.imread('../dataset/depth/gazefollow_extended/test2/00000000/00000017.jpg')
# Out:
# array([[[165, 161, 172],
#         [181, 177, 188],
#         [211, 208, 217],
#         ...,
#         [ 68,  82,  88],
#         [100, 111, 119],
#         [ 76,  87,  95]],
#
#        [[156, 152, 163],
#         [144, 140, 151],
#         [217, 214, 223],
#         ...,
#         [ 73,  85,  91],
#         [ 92, 103, 111],
#         [ 72,  83,  91]],
#
#        [[165, 161, 172],
#         [168, 164, 175],
#         [164, 161, 170],
#         ...,
#         [ 82,  92,  99],
#         [ 89,  98, 107],
#         [ 80,  89,  99]],
#
#        ...,
#
#        [[246, 237, 228],
#         [248, 239, 230],
#         [251, 242, 232],
#         ...,
#         [212, 207, 204],
#         [216, 211, 208],
#         [213, 208, 205]],
#
#        [[245, 236, 227],
#         [247, 238, 229],
#         [250, 241, 231],
#         ...,
#         [187, 182, 181],
#         [193, 188, 187],
#         [189, 184, 183]],
#
#        [[244, 235, 226],
#         [246, 237, 228],
#         [248, 239, 229],
# ...
